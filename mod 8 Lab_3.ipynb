# %% [markdown]
# <a href="https://colab.research.google.com/github/Nunnakarthik/Fmml--module/blob/main/mod%208%20Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-14 06:53:49--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   185MB/s    in 0.4s
#
# 2025-03-14 06:53:50 (185 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 20847  1703.08762v1  Whether teaching in a classroom or a Massive O...    cs
# 26558  1611.02200v1  We study the problem of transferring a sample ...    cs
# 3068   1711.10563v2  Incremental class learning involves sequential...    cs
# 11207  1501.05740v1  We develop latent variable models for Bayesian...  stat
# 30990  1802.00539v1  Classifying large scale networks into several ...    cs
# ...             ...                                                ...   ...
# 17751  1802.07089v1  This paper proposes a new architecture - Atten...    cs
# 14673   0911.1516v2  This paper presents a theoretical research bas...    cs
# 22478  1609.00285v4  Sparse coding is a core building block in many...  stat
# 2675   1705.07347v3  Thompson sampling has emerged as an effective ...  stat
# 2550   1603.00788v1  Probabilistic modeling is iterative. A scienti...  stat
#
#                                                    title  year  \
# 20847  Team Formation for Scheduling Educational Mate...  2017
# 26558         Unsupervised Cross-Domain Image Generation  2016
# 3068   FearNet: Brain-Inspired Model for Incremental ...  2017
# 11207  Bayesian Learning for Low-Rank matrix reconstr...  2015
# 30990  Complex Network Classification with Convolutio...  2018
# ...                                                  ...   ...
# 17751  Attentive Tensor Product Learning for Language...  2018
# 14673  A Discourse-based Approach in Text-based Machi...  2009
# 22478  Understanding Trainable Sparse Coding via Matr...  2016
# 2675                                   Ensemble Sampling  2017
# 2550     Automatic Differentiation Variational Inference  2016
#
#                                                 keywords
# 20847  [classroom, important, objective, maximally, i...
# 26558  [transferring, generative, unchanged, unsuperv...
# 3068   [incremental, sequentially, assumptions, catas...
# 11207  [completion, reconstruction, measurements, det...
# 30990  [classifying, categories, distinguishing, acco...
# ...                                                  ...
# 17751  [architecture, attentive, represent, grammatic...
# 14673  [theoretical, resolution, translation, discour...
# 22478  [pipelines, typically, optimization, technique...
# 2675   [effective, heuristic, algorithm, computing, p...
# 2550   [probabilistic, iterative, scientist, accordin...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 20847    [classroom, important, objective, maximally, i...
# 26558    [transferring, generative, unchanged, unsuperv...
# 3068     [incremental, sequentially, assumptions, catas...
# 11207    [completion, reconstruction, measurements, det...
# 30990    [classifying, categories, distinguishing, acco...
#                                ...
# 3091     [concerned, unsupervised, structure, determina...
# 22245    [sequential, classification, repeatedly, selec...
# 6219     [difficult, numerical, describing, therefore, ...
# 17042    [linguistic, resources, extensively, statistic...
# 19969    [representing, reasoning, knowledge, dependent...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8782 words.
# Out of those 4561 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="501fb849-6ed8-4f46-b357-4eaf8d2064c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("501fb849-6ed8-4f46-b357-4eaf8d2064c2")) {                    Plotly.newPlot(                        "501fb849-6ed8-4f46-b357-4eaf8d2064c2",                        [{"x":["different","classroom","activities","formation","experiments","department","polynomial","interaction","algorithm","objective","important","properties","effective","maximized","maximally","education","educational","synthetic","potential","contribution","scheduling","including","demonstrate","component","constancy","generation","unchanged","generative","themselves","regularizing","convincing","previously","preserving","multiclass","transferring","encourages","unsupervised","classification","determining","challenging","catastrophic","hippocampal","sequentially","forgetting","incremental","assumptions","consolidation","efficient","mammalian","mechanisms","performance","benchmarks","relations","numerical","determined","functions","structured","measurements","parameters","covariance","evaluated","expectation","maximization","extensive","completion","simulations","kronecker","reconstruct","reconstruction","approximation","promoting","developed","automatically","classifying","classifiers","conventional","embedding","classifier","integrating","applications","clustering","according","robustness","euclidean","importance","convolutional","structures","comparison","international","distinguishing","categories","framework","specifically","stochastic","generates","explicitly","generating","competitive","definition","generalization","specifying","highlighted","wasserstein","desirable","distribution","prediction","significantly","substantially","procedures","maintains","subpopulation","association","alternatives","investigate","heterogeneity","illustrates","variables","observations","nonparametric","attributable","pronounced","correlation","heterogeneous","algorithms","complexity","graphical","unconditional","underlying","neighborhoods","exhaustively","computational","interpolates","statistical","difficult","notoriously","montanari","depending","structure","undirected","introduced","ferromagnetic","repulsion","threshold","structural","restricting","conditional","conditioning","favorably","developing","implement","elimination","discovering","limitation","dependence","proposing","selection","multivariate","combinations","observational","simultaneous","empirically","estimates","evaluates","geological","integration","consideration","information","individually","correlations","performed","quantities","processes","demonstrates","illustrating","technique","linguistic","assessment","sufficient","comparing","characterization","comparable","presenting","triangular","approximate","independent","furthermore","estimation","regularization","establish","dimensional","conditions","regression","correlated","coefficients","particular","uncorrelated","accurately","characterize","completely","regardless"],"y":[759,1,28,15,597,4,57,86,826,171,359,196,272,5,8,3,6,131,157,78,19,246,582,112,5,130,6,109,22,6,5,88,50,8,12,13,166,521,36,261,7,1,20,7,33,67,1,417,3,46,874,102,92,84,42,220,112,56,263,24,130,42,35,188,35,35,2,41,107,116,7,205,184,32,124,117,123,149,36,401,165,108,119,36,92,368,130,154,7,12,58,575,177,126,68,72,106,106,48,112,7,7,6,34,223,234,259,29,39,16,2,26,21,158,6,9,130,85,17,1,5,79,42,619,245,55,1,115,7,4,286,1,164,141,3,1,29,334,14,155,0,2,31,49,7,94,11,22,66,70,8,28,27,24,24,148,20,28,6,33,72,70,13,0,57,31,725,10,33,116,6,102,60,5,288,77,45,81,72,29,109,20,4,93,130,191,224,69,47,193,150,133,29,48,252,2,68,49,37,15],"type":"bar"},{"x":["different","classroom","activities","formation","experim ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4561,), (4561, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7833333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Large</span> <span style=''>Pose</span> <span style=''>3D</span> <span style=''>Face</span> <span style='background-color:rgba(0, 255, 0, 0.43624161073825507);'>Reconstruction</span> <span style=''>from</span> <span style=''>a</span> <span style=''>Single</span> <span style=''>Image</span> <span style=''>via</span> <span style=''>Direct</span> <span style='background-color:rgba(0, 255, 0, 0.875);'>Volumetric</span> <span style=''>CNN</span> <span style='background-color:rgba(255, 0, 0, 0.47945205479452063);'>Regression</span> <br/><br/><span style=''>3D</span> <span style=''>face</span> <span style='background-color:rgba(0, 255, 0, 0.43624161073825507);'>reconstruction</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fundamental</span> <span style=''>Computer</span> <span style=''>Vision</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>extraordinary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficulty</span> <span style=''>Current</span> <span style=''>systems</span> <span style=''>often</span> <span style=''>assume</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5384615384615384);'>availability</span> <span style=''>of</span> <span style=''>multiple</span> <span style=''>facial</span> <span style=''>images</span> <span style=''>(sometimes</span> <span style=''>from</span> <span style=''>the</span> <span style=''>same</span> <span style=''>subject)</span> <span style=''>as</span> <span style=''>input</span> <span style=''>and</span> <span style=''>must</span> <span style=''>address</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodological</span> <span style='background-color:rgba(0, 255, 0, 0.31147540983606553);'>challenges</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714286);'>establishing</span> <span style=''>dense</span> <span style='background-color:rgba(0, 255, 0, 0.75);'>correspondences</span> <span style=''>across</span> <span style=''>large</span> <span style=''>facial</span> <span style=''>poses</span> <span style='background-color:rgba(0, 255, 0, 0.3103448275862069);'>expressions</span> <span style=''>and</span> <span style=''>non</span> <span style=''>uniform</span> <span style='background-color:rgba(0, 255, 0, 0.9523809523809524);'>illumination</span> <span style=''>In</span> <span style=''>general</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>require</span> <span style=''>complex</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inefficient</span> <span style='background-color:rgba(0, 255, 0, 0.6363636363636364);'>pipelines</span> <span style=''>for</span> <span style=''>model</span> <span style=''>building</span> <span style=''>and</span> <span style=''>fitting</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>address</span> <span style=''>many</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>limitations</span> <span style=''>by</span> <span style=''>training</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.6283185840707964);'>Convolutional</span> <span style=''>Neural</span> <span style=''>Network</span> <span style=''>(CNN)</span> <span style=''>on</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>appropriate</span> <span style=''>dataset</span> <span style='background-color:rgba(0, 255, 0, 0.4117647058823529);'>consisting</span> <span style=''>of</span> <span style=''>2D</span> <span style=''>images</span> <span style=''>and</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Optimal</span> <span style=''>variable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>in</span> <span style=''>multi</span> <span style=''>group</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discriminant</span> <span style=''>analysis</span> <br/><br/><span style=''>This</span> <span style=''>article</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considers</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>multi</span> <span style=''>group</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>in</span> <span style=''>the</span> <span style=''>setting</span> <span style=''>where</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>p</span> <span style=''>is</span> <span style=''>larger</span> <span style=''>than</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>n</span> <span style=''>Several</span> <span style=''>methods</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>that</span> <span style=''>address</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>however</span> <span style=''>their</span> <span style=''>variable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>is</span> <span style=''>either</span> <span style=''>unknown</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>suboptimal</span> <span style=''>to</span> <span style=''>the</span> <span style=''>results</span> <span style=''>known</span> <span style=''>in</span> <span style=''>the</span> <span style=''>two</span> <span style=''>group</span> <span style=''>case</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>sharp</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style=''>recovery</span> <span style=''>of</span> <span style=''>relevant</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>in</span> <span style=''>the</span> <span style=''>multi</span> <span style=''>group</span> <span style=''>case</span> <span style=''>using</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discriminant</span> <span style=''>analysis</span> <span style=''>proposal</span> <span style=''>of</span> <span style=''>Gaynanova</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2014</span> <span style=''>We</span> <span style=''>achieve</span> <span style=''>the</span> <span style=''>rates</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>that</span> <span style=''>attain</span> <span style=''>the</span> <span style=''>optimal</span> <span style=''>scaling</span> <span style=''>of</span> <span style=''>the</span> <span style=''>sample</span> <span style=''>size</span> <span style=''>n</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>p</span> <span style=''>and</span> <span style=''>the</span> <span style=''>sparsity</span> <span style=''>level</span> <span style=''>s</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Small</span> <span style=''>sample</span> <span style=''>Brain</span> <span style=''>Mapping</span> <span style=''>Sparse</span> <span style=''>Recovery</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.5294117647058824);'>Spatially</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Correlated</span> <span style=''>Designs</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Randomization</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.361344537815126);'>Functional</span> <span style='background-color:rgba(255, 0, 0, 0.7);'>neuroimaging</span> <span style=''>can</span> <span style=''>measure</span> <span style=''>the</span> <span style=''>brains</span> <span style=''>response</span> <span style=''>to</span> <span style=''>an</span> <span style=''>external</span> <span style=''>stimulus</span> <span style=''>It</span> <span style=''>is</span> <span style=''>used</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>brain</span> <span style=''>mapping</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifying</span> <span style=''>from</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.30327868852459017);'>observations</span> <span style=''>the</span> <span style=''>brain</span> <span style=''>regions</span> <span style=''>involved</span> <span style=''>This</span> <span style=''>problem</span> <span style=''>can</span> <span style=''>be</span> <span style=''>cast</span> <span style=''>into</span> <span style=''>a</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>task</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.7);'>neuroimaging</span> <span style=''>data</span> <span style=''>are</span> <span style=''>used</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.38181818181818183);'>predictors</span> <span style=''>for</span> <span style=''>the</span> <span style=''>stimulus</span> <span style=''>Brain</span> <span style=''>mapping</span> <span style=''>is</span> <span style=''>then</span> <span style=''>seen</span> <span style=''>as</span> <span style=''>a</span> <span style=''>support</span> <span style=''>recovery</span> <span style=''>problem</span> <span style=''>On</span> <span style='background-color:rgba(255, 0, 0, 0.361344537815126);'>functional</span> <span style=''>MRI</span> <span style=''>(fMRI)</span> <span style=''>data</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particularly</span> <span style='background-color:rgba(0, 255, 0, 0.4223433242506811);'>challenging</span> <span style=''>as</span> <span style=''>i)</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>samples</span> <span style=''>is</span> <span style=''>small</span> <span style=''>due</span> <span style=''>to</span> <span style=''>limited</span> <span style='background-color:rgba(0, 255, 0, 0.4375);'>acquisition</span> <span style=''>time</span> <span style=''>and</span> <span style=''>ii)</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3643031784841076);'>variables</span> <span style=''>are</span> <span style=''>strongly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlated</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>overcome</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficulties</span> <span style=''>using</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.479452054794 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Ranking</span> <span style=''>via</span> <span style=''>Sinkhorn</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Propagation</span> <br/><br/><span style=''>It</span> <span style=''>is</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importance</span> <span style=''>to</span> <span style=''>develop</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>ranking</span> <span style=''>In</span> <span style=''>contrast</span> <span style=''>to</span> <span style=''>many</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objectives</span> <span style=''>however</span> <span style=''>the</span> <span style=''>ranking</span> <span style=''>problem</span> <span style=''>presents</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficulties</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>fact</span> <span style=''>that</span> <span style=''>the</span> <span style=''>space</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>permutations</span> <span style=''>is</span> <span style=''>not</span> <span style=''>smooth</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>examine</span> <span style=''>the</span> <span style=''>class</span> <span style=''>of</span> <span style=''>rank</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>which</span> <span style=''>includes</span> <span style=''>popular</span> <span style=''>metrics</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discounted</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>cumulative</span> <span style=''>gain</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>observe</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expectations</span> <span style=''>of</span> <span style=''>these</span> <span style=''>gains</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completely</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterized</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>marginals</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>permutation</span> <span style=''>matrices</span> <span style=''>Thus</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expectations</span> <span style=''>of</span> <span style=''>rank</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objectives</span> <span style=''>can</span> <span style=''>always</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>described</span> <span style=''>through</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>locations</span> <span style=''>in</span> <span style=''>the</span> <span style=''>Birkhoff</span> <span style=''>polytope</span> <span style=''>ie</span> <span style=''>doubly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>matrices</span> <span style=''>(DSMs)</span> <span style=''>We</span>  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07132718239886444)
# 	processing (0.10681334279630944)
# 	segmentation (0.06990773598296664)
# 	experimental (0.13520227111426544)
# 	representation (0.14229950319375442)
# 	information (0.2572746628814762)
# 	detection (0.12739531582682753)
# 	different (0.26933995741660754)
# 	convolutional (0.13058907026259758)
# 	recognition (0.1263307310149042)
#
# Some Statistics words are:
# 	stochastic (0.13723511604439959)
# 	theoretical (0.15590312815338042)
# 	statistical (0.15237134207870837)
# 	variables (0.14076690211907164)
# 	algorithm (0.39354187689202824)
# 	estimation (0.18012108980827446)
# 	distribution (0.1856710393541877)
# 	dimensional (0.19021190716448033)
# 	inference (0.20181634712411706)
# 	regression (0.19071644803229063)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cc5ed2a7-f315-4526-9b00-05d1823b7f43" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc5ed2a7-f315-4526-9b00-05d1823b7f43")) {                    Plotly.newPlot(                        "cc5ed2a7-f315-4526-9b00-05d1823b7f43",                        [{"x":["different","classroom","activities","formation","experiments","department","polynomial","interaction","algorithm","objective","important","properties","effective","maximized","maximally","education","educational","synthetic","potential","contribution","scheduling","including","demonstrate","component","constancy","generation","unchanged","generative","themselves","regularizing","convincing","previously","preserving","multiclass","transferring","encourages","unsupervised","classification","determining","challenging","catastrophic","hippocampal","sequentially","forgetting","incremental","assumptions","consolidation","efficient","mammalian","mechanisms","performance","benchmarks","relations","numerical","determined","functions","structured","measurements","parameters","covariance","evaluated","expectation","maximization","extensive","completion","simulations","kronecker","reconstruct","reconstruction","approximation","promoting","developed","automatically","classifying","classifiers","conventional","embedding","classifier","integrating","applications","clustering","according","robustness","euclidean","importance","convolutional","structures","comparison","international","distinguishing","categories","framework","specifically","stochastic","generates","explicitly","generating","competitive","definition","generalization","specifying","highlighted","wasserstein","desirable","distribution","prediction","significantly","substantially","procedures","maintains","subpopulation","association","alternatives","investigate","heterogeneity","illustrates","variables","observations","nonparametric","attributable","pronounced","correlation","heterogeneous","algorithms","complexity","graphical","unconditional","underlying","neighborhoods","exhaustively","computational","interpolates","statistical","difficult","notoriously","montanari","depending","structure","undirected","introduced","ferromagnetic","repulsion","threshold","structural","restricting","conditional","conditioning","favorably","developing","implement","elimination","discovering","limitation","dependence","proposing","selection","multivariate","combinations","observational","simultaneous","empirically","estimates","evaluates","geological","integration","consideration","information","individually","correlations","performed","quantities","processes","demonstrates","illustrating","technique","linguistic","assessment","sufficient","comparing","characterization","comparable","presenting","triangular","approximate","independent","furthermore","estimation","regularization","establish","dimensional","conditions","regression","correlated","coefficients","particular","uncorrelated","accurately","characterize","completely","regardless","sequences","neuromuscular","simulation","characterized","adaptation","practitioners","corresponding","subsequently","extracted","parameter","immediately","described","practitioner","comparatively","constrained","hypothetical","resistance","extracting","development","investment","adjustment","capability","application","predicted","effortlessly","scientific","characteristics","manipulate","monitoring","disciplines","contextualized","membership","represented","interactions","interacting","accompanied","biological","connectomics","regularized","covariate","interpret","modification","diffusion","contextualizing","covariates","generated","guarantees","canonical","simulated","achieving","communities","location ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	ferromagnetic
# 	geological
# 	nonconjugate
# 	intermittent
# 	candecompparafac
# 	preconditioned
# 	exponents
# 	textitnon
# 	geostatistical
# 	misspecification
# 	equitability
# 	equitable
# 	preconditioning
# 	heteroskedastic
# 	excluding
# 	stragglers
# 	straggler
# 	emphmulti
# 	reconstructive
# 	prohibits
# Some words which never appear in Statistics papers:
# 	constancy
# 	mammalian
# 	neuromuscular
# 	effortlessly
# 	strengthened
# 	repeating
# 	responsive
# 	overarching
# 	utterance
# 	rejecting
# 	characterness
# 	multiplicity
# 	ethnicity
# 	enumerates
# 	terminated
# 	coalitions
# 	coalition
# 	containment
# 	templates
# 	photographic

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0542744571027155e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7241666666666666
